# %% [markdown]
# <a href="https://colab.research.google.com/github/XiaoLiang28/Datamanagement/blob/main/binary_choice_code_part_1_Xiao_Liang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
class PayoffMatrix:
    def __init__(self, p1, p2, p3, p4, a1, a2, a3, a4):
        self.p1 = p1
        self.p2 = p2
        self.p3 = p3
        self.p4 = p4

        self.a1 = a1
        self.a2 = a2
        self.a3 = a3
        self.a4 = a4

# %%
class Agent:
    def __init__(self, agent_id, agent_type):
       self.agent_id = agent_id
       self.agent_type = agent_type
       self.utility = 0

    def introduce(self):
        print(f"I am {self.agent_id} and my type is {self.agent_type}")
        print(f"My utility is {self.utility}")
